# %% [markdown]
# #**Football Analysis System**

# %%
# !nvidia-smi

# %% [markdown]
# **Step 01 # Install the Ultralytics Package**

# %%
# !pip install ultralytics

# %% [markdown]
# **Step 02 # Import All the Requried Libraries**

# %%
import ultralytics
ultralytics.checks()

# %%
from ultralytics import YOLO
from IPython.display import Image

# %% [markdown]
# **Step # 03 Download Dataset from Roboflow**

# %%
# !pip install roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="z1uD0b9XOZdnivUdFkEd")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov11")

# %%
dataset.location

# %% [markdown]
# **Step # 04 Train YOLO11 Model on a Custom Dataset**

# %%
# !yolo task=detect mode=train data={dataset.location}/data.yaml model="yolo11l.pt" epochs=80 imgsz=640

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !mv "/content/runs/detect/train2/weights/best.pt" "/content/drive/MyDrive/FOOTBALL_YOLO11"
