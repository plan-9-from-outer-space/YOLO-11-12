# %% [markdown]
# **Install the Ultralytics Package**

# %%
# !pip install ultralytics

# %% [markdown]
# **Import All the Required Libraries**

# %%
import ultralytics
from ultralytics import YOLO
from IPython.display import Image

# %% [markdown]
# **Check Ultralytics Version**

# %%
ultralytics.checks()

# %% [markdown]
# **Download the Licence Plate Dataset from Roboflow**

# %%
# !pip install roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="z1uD0b9XOZdnivUdFkEd")
project = rf.workspace("augmented-startups").project("vehicle-registration-plates-trudk")
version = project.version(1)
dataset = version.download("yolov11")

# %% [markdown]
# **Load the YOLO11 Model**

# %%
model = YOLO("yolo11n.pt")

# %% [markdown]
# **Train/ Fine-Tune the YOLO11 Model on Licence Plate Dataset**

# %% [markdown]
# Before starting the traing please make sure to update the train and validation image dataset paths

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
! rm -rf runs/

# %%
#Train the Model
results = model.train(data = "/content/Vehicle-Registration-Plates-1/data.yaml", epochs = 5, imgsz = 640, batch = 16)

# %% [markdown]
# **Download Demo Videos from Google Drive**

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !gdown "https://drive.google.com/uc?id=1zXjDZGwWZTkoKVo1egr80Uzive6hsAXh&confirm=t"

# %%
# !gdown "https://drive.google.com/uc?id=1AxWXm1VgqfT33kn5epBfnazpkEuunuSf&confirm=t"

# %%
# !gdown "https://drive.google.com/uc?id=1zsAx95np_vH5gyUqx7w5yQ_v593__TyF&confirm=t"

# %%
# !gdown "https://drive.google.com/uc?id=1i3zO0eroYm9OYs4yse9VxGT2gdv5NH5P&confirm=t"

# %% [markdown]
# **Inference**

# %%
#Load the Trained Model
# !gdown "https://drive.google.com/uc?id=1nBw2dc5KklvljpSI3s2eAcPSXyqz2sdJ&confirm=t"

# %%
model = YOLO("/content/best.pt")

# %%
results = model.predict(source = "/content/1.mp4", save = True, conf = 0.60, iou = 0.2)

# %%
# !rm "/content/result_compressed.mp4"

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# Input video path
save_path = '/content/runs/detect/predict/1.avi'

# Compressed video path
compressed_path = "/content/result_compressed.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)

# %%
results = model.predict(source = "/content/2.mp4", save = True, conf = 0.50, iou = 0.2)

# %%
# !rm "/content/result_compressed.mp4"

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# Input video path
save_path = '/content/runs/detect/predict/2.avi'

# Compressed video path
compressed_path = "/content/result_compressed.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)

# %%
results = model.predict(source = "/content/3.mp4", save = True, conf = 0.50, iou = 0.2)

# %%
# !rm "/content/result_compressed.mp4"

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# Input video path
save_path = '/content/runs/detect/predict/3.avi'

# Compressed video path
compressed_path = "/content/result_compressed.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)

# %%
results = model.predict(source = "/content/4.mp4", save = True, conf = 0.50, iou = 0.2)

# %%
# !rm "/content/result_compressed.mp4"

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# Input video path
save_path = '/content/runs/detect/predict/4.avi'

# Compressed video path
compressed_path = "/content/result_compressed.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
